# %% [markdown]
# # Generate questions for the test

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Preprocess table 1
# The data is parsed as html table from [here](https://psycabi.net/testy/388-test-bolshaya-pyaterka-pyatifaktornyj-lichnostnyj-oprosnik-r-makkrae-p-kosta-metodika-diagnostiki-lichnostnykh-faktorov-temperamenta-i-kharaktera-5pfq)

# %%
# read the txt file with html table body content
with open("html_table_1.txt", "r") as file:
    table_body = file.read()

# convert the table body to a dataframe
table_df_1 = pd.read_html(table_body)[0]

# Create new text column as text0 + text1 and remove first number and dot
table_df_1[0] = table_df_1[0].str.replace(r"^\d+\.\s", "", regex=True)
table_df_1["Questions"] = "Оцените противопоставление:\n\n1. " + table_df_1[0] + "\nи\n2. " + table_df_1[6]


# Add answer columns filled with "Соглашусь с 1", "Скорее соглашусь с 1", "Не знаю", "Скорее соглашусь с 2", "Соглашусь с 2"
table_df_1 = table_df_1.assign(Ans_1="Соглашусь с 1", Ans_2="Скорее 1", Ans_3="Не знаю", Ans_4="Скорее 2", Ans_5="Соглашусь с 2")

# drop first 7 columns
table_df_1 = table_df_1.drop([0, 1, 2, 3, 4, 5, 6], axis=1)

# add required column
table_df_1["Required"] = True

# add column for imported from and index
table_df_1["Imported_From"] = "test_1"
table_df_1["Index"] = range(0, len(table_df_1))

table_df_1
# Out:
#                                             Questions          Ans_1  \
# 0   Оцените противопоставление:\n\n1. Мне нравится...  Соглашусь с 1
# 1   Оцените противопоставление:\n\n1. Люди считают...  Соглашусь с 1
# 2   Оцените противопоставление:\n\n1. Я во всем це...  Соглашусь с 1
# 3   Оцените противопоставление:\n\n1. Меня часто б...  Соглашусь с 1
# 4   Оцените противопоставление:\n\n1. Все новое вы...  Соглашусь с 1
# ..                                                ...            ...
# 70  Оцените противопоставление:\n\n1. Мне нравится...  Соглашусь с 1
# 71  Оцените противопоставление:\n\n1. Некоторые го...  Соглашусь с 1
# 72  Оцените противопоставление:\n\n1. Я точно и ме...  Соглашусь с 1
# 73  Оцените противопоставление:\n\n1. Иногда я быв...  Соглашусь с 1
# 74  Оцените противопоставление:\n\n1. Иногда я чув...  Соглашусь с 1
#
#        Ans_2    Ans_3     Ans_4          Ans_5  Required Imported_From  Index
# 0   Скорее 1  Не знаю  Скорее 2  Соглашусь с 2      True        test_1      0
# 1   Скорее 1  Не знаю  Скорее 2  Соглашусь с 2      True        test_1      1
# 2   Скорее 1  Не знаю  Скорее 2  Соглашусь с 2      True        test_1      2
# 3   Скорее 1  Не знаю  Скорее 2  Соглашусь с 2      True        test_1      3
# 4   Скорее 1  Не знаю  Скорее 2  Соглашусь с 2      True        test_1      4
# ..       ...      ...       ...            ...       ...           ...    ...
# 70  Скорее 1  Не знаю  Скорее 2  Соглашусь с 2      True        test_1     70
# 71  Скорее 1  Не знаю  Скорее 2  Соглашусь с 2      True        test_1     71
# 72  Скорее 1  Не знаю  Скорее 2  Соглашусь с 2      True        test_1     72
# 73  Скорее 1  Не знаю  Скорее 2  Соглашусь с 2      True        test_1     73
# 74  Скорее 1  Не знаю  Скорее 2  Соглашусь с 2      True        test_1     74
#
# [75 rows x 9 columns]

# %% [markdown]
# ### Preprocess table 2
# The data is parsed as html table from [here](https://studme.org/125008/psihologiya/koping_povedenie_stressovyh_situatsiyah)

# %%
# Df for stacking the table body
table_df_2 = pd.DataFrame(columns=["Questions", "Ans_1", "Ans_2", "Ans_3", "Ans_4", "Ans_5"])

# read the txt file with html table body content
for i in range(1, 4):
    with open(f"html_table_2_{i}.txt", "r") as file:
        table_body = file.read()

    # convert the table body to a dataframe
    table_body_df = pd.read_html(table_body)[0]

    # drop first row
    table_body_df = table_body_df.drop(0)

    # drop first column
    table_body_df = table_body_df.drop(0, axis=1)

    # rename columns
    table_body_df.columns = ["Questions", "Ans_1", "Ans_2", "Ans_3", "Ans_4", "Ans_5"]

    # append to df
    table_df_2 = table_df_2.append(table_body_df, ignore_index=True)

# for the last row set answers as 1, 2, 3, 4, 5 (костыль)
table_df_2.iloc[-1, 1:] = [1, 2, 3, 4, 5]


# For each question for 60% probability make it lowercase and add "Я"
for i in range(0, len(table_df_2)):
    if np.random.rand() < 0.6:
        table_df_2["Questions"].iloc[i] = f"Оцените утверждение:" \
                                          f"" \
                                          f"Я {table_df_2['Questions'].iloc[i].lower()}"
    else:
        table_df_2["Questions"].iloc[i] = f"Оцените утверждение:\n\n{table_df_2['Questions'].iloc[i]}"

# set all answers to "Не соглашусь", "Скорее не соглашусь", "Не знаю", "Скорее соглашусь", "Соглашусь"
table_df_2.iloc[:, 1:] = ["Не соглашусь", "Скорее не соглашусь", "Не знаю", "Скорее соглашусь", "Соглашусь"]

# add required column
table_df_2["Required"] = True

# add column for imported from and index
table_df_2["Imported_From"] = "test_2"
table_df_2["Index"] = range(0, len(table_df_2))

table_df_2
# Out:
#                                             Questions         Ans_1  \
# 0   Оцените утверждение:\n\nЯ стараюсь тщательно р...  Не соглашусь
# 1   Оцените утверждение:\n\nСосредоточиваюсь на пр...  Не соглашусь
# 2   Оцените утверждение:\n\nЯ думаю о чем-то хорош...  Не соглашусь
# 3      Оцените утверждение:\n\nСтараюсь быть на людях  Не соглашусь
# 4   Оцените утверждение:\n\nВиню себя за нерешител...  Не соглашусь
# 5   Оцените утверждение:\n\nЯ делаю то, что считаю...  Не соглашусь
# 6   Оцените утверждение:\n\nПогружаюсь в свою боль...  Не соглашусь
# 7   Оцените утверждение:\n\nВиню себя за то, что о...  Не соглашусь
# 8   Оцените утверждение:\n\nЯ хожу по магазинам, н...  Не соглашусь
# 9   Оцените утверждение:\n\nЯ думаю о том, что для...  Не соглашусь
# 10    Оцените утверждение:\n\nЯ стараюсь больше спать  Не соглашусь
# 11    Оцените утверждение:\n\nБалую себя любимой едой  Не соглашусь
# 12  Оцените утверждение:\n\nПереживаю, что не могу...  Не соглашусь
# 13  Оцените утверждение:\n\nЯ позволяю себе нервни...  Не соглашусь
# 14  Оцените утверждение:\n\nЯ вспоминаю, как я реш...  Не соглашусь
# 15  Оцените утверждение:\n\nГоворю себе, что это п...  Не соглашусь
# 16  Оцените утверждение:\n\nВиню себя за слишком э...  Не соглашусь
# 17  Оцените утверждение:\n\nЯ иду куда-нибудь пере...  Не соглашусь
# 18  Оцените утверждение:\n\nЯ испытываю эмоциональ...  Не соглашусь
# 19  Оцените утверждение:\n\nЯ покупаю себе какую-н...  Не соглашусь
# 20  Оцените утверждение:\n\nОпределяю курс действи...  Не соглашусь
# 21  Оцените утверждение:\n\nЯ обвиняю себя за то, ...  Не соглашусь
# 22  Оцените утверждение:\n\nЯ иду на вечеринку, в ...  Не соглашусь
# 23  Оцените утверждение:\n\nЯ стараюсь вникнуть в ...  Не соглашусь
# 24  Оцените утверждение:\n\nЯ застываю, «заморажив...  Не соглашусь
# 25  Оцените утверждение:\n\nНемедленно предпринима...  Не соглашусь
# 26  Оцените утверждение:\n\nОбдумываю случившееся ...  Не соглашусь
# 27  Оцените утверждение:\n\nЯ жалею, что не могу и...  Не соглашусь
# 28        Оцените утверждение:\n\nИду в гости к другу  Не соглашусь
# 29  Оцените утверждение:\n\nНервничаю и беспокоюсь...  Не соглашусь
# 30  Оцените утверждение:\n\nПровожу время с дороги...  Не соглашусь
# 31          Оцените утверждение:\n\nЯ иду на прогулку  Не соглашусь
# 32  Оцените утверждение:\n\nЯ говорю себе, что это...  Не соглашусь
# 33  Оцените утверждение:\n\nЯ сосредоточиваюсь на ...  Не соглашусь
# 34  Оцените утверждение:\n\nРазговариваю с тем, че...  Не соглашусь
# 35  Оцените утверждение:\n\nЯ анализирую проблему,...  Не соглашусь
# 36                Оцените утверждение:\n\nЗвоню другу  Не соглашусь
# 37    Оцените утверждение:\n\nЯ испытываю раздражение  Не соглашусь
# 38  Оцените утверждение:\n\nЯ решаю, что теперь ва...  Не соглашусь
# 39  Оцените утверждение:\n\nСмотрю телевизор или в...  Не соглашусь
# 40       Оцените утверждение:\n\nКонтролирую ситуацию  Не соглашусь
# 41  Оцените утверждение:\n\nПрилагаю дополнительны...  Не соглашусь
# 42  Оцените утверждение:\n\nРазрабатываю несколько...  Не соглашусь
# 43  Оцените утверждение:\n\nЯ беру отпуск или отгу...  Не соглашусь
# 44    Оцените утверждение:\n\nЯ отыгрываюсь на других  Не соглашусь
# 45  Оцените утверждение:\n\nИспользую ситуацию, чт...  Не соглашусь
# 46  Оцените утверждение:\n\nСтараюсь собраться, чт...  Не соглашусь
# 47  Оцените утверждение:\n\nЯ смотрю телевизор или...  Не соглашусь
#
#                   Ans_2    Ans_3             Ans_4      Ans_5  Required  \
# 0   Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 1   Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 2   Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 3   Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 4   Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 5   Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 6   Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 7   Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 8   Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 9   Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 10  Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 11  Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 12  Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 13  Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 14  Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 15  Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 16  Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 17  Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 18  Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 19  Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 20  Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 21  Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 22  Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 23  Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 24  Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 25  Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 26  Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 27  Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 28  Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 29  Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 30  Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 31  Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 32  Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 33  Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 34  Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 35  Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 36  Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 37  Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 38  Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 39  Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 40  Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 41  Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 42  Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 43  Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 44  Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 45  Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 46  Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
# 47  Скорее не соглашусь  Не знаю  Скорее соглашусь  Соглашусь      True
#
#    Imported_From  Index
# 0         test_2      0
# 1         test_2      1
# 2         test_2      2
# 3         test_2      3
# 4         test_2      4
# 5         test_2      5
# 6         test_2      6
# 7         test_2      7
# 8         test_2      8
# 9         test_2      9
# 10        test_2     10
# 11        test_2     11
# 12        test_2     12
# 13        test_2     13
# 14        test_2     14
# 15        test_2     15
# 16        test_2     16
# 17        test_2     17
# 18        test_2     18
# 19        test_2     19
# 20        test_2     20
# 21        test_2     21
# 22        test_2     22
# 23        test_2     23
# 24        test_2     24
# 25        test_2     25
# 26        test_2     26
# 27        test_2     27
# 28        test_2     28
# 29        test_2     29
# 30        test_2     30
# 31        test_2     31
# 32        test_2     32
# 33        test_2     33
# 34        test_2     34
# 35        test_2     35
# 36        test_2     36
# 37        test_2     37
# 38        test_2     38
# 39        test_2     39
# 40        test_2     40
# 41        test_2     41
# 42        test_2     42
# 43        test_2     43
# 44        test_2     44
# 45        test_2     45
# 46        test_2     46
# 47        test_2     47

# %%
# merge the two dataframes
final_df = pd.concat([table_df_1, table_df_2], ignore_index=True)

final_df
# Out:
#                                              Questions          Ans_1  \
# 0    Оцените противопоставление:\n\n1. Мне нравится...  Соглашусь с 1
# 1    Оцените противопоставление:\n\n1. Люди считают...  Соглашусь с 1
# 2    Оцените противопоставление:\n\n1. Я во всем це...  Соглашусь с 1
# 3    Оцените противопоставление:\n\n1. Меня часто б...  Соглашусь с 1
# 4    Оцените противопоставление:\n\n1. Все новое вы...  Соглашусь с 1
# ..                                                 ...            ...
# 118  Оцените утверждение:\n\nЯ беру отпуск или отгу...   Не соглашусь
# 119    Оцените утверждение:\n\nЯ отыгрываюсь на других   Не соглашусь
# 120  Оцените утверждение:\n\nИспользую ситуацию, чт...   Не соглашусь
# 121  Оцените утверждение:\n\nСтараюсь собраться, чт...   Не соглашусь
# 122  Оцените утверждение:\n\nЯ смотрю телевизор или...   Не соглашусь
#
#                    Ans_2    Ans_3             Ans_4          Ans_5  Required  \
# 0               Скорее 1  Не знаю          Скорее 2  Соглашусь с 2      True
# 1               Скорее 1  Не знаю          Скорее 2  Соглашусь с 2      True
# 2               Скорее 1  Не знаю          Скорее 2  Соглашусь с 2      True
# 3               Скорее 1  Не знаю          Скорее 2  Соглашусь с 2      True
# 4               Скорее 1  Не знаю          Скорее 2  Соглашусь с 2      True
# ..                   ...      ...               ...            ...       ...
# 118  Скорее не соглашусь  Не знаю  Скорее соглашусь      Соглашусь      True
# 119  Скорее не соглашусь  Не знаю  Скорее соглашусь      Соглашусь      True
# 120  Скорее не соглашусь  Не знаю  Скорее соглашусь      Соглашусь      True
# 121  Скорее не соглашусь  Не знаю  Скорее соглашусь      Соглашусь      True
# 122  Скорее не соглашусь  Не знаю  Скорее соглашусь      Соглашусь      True
#
#     Imported_From  Index
# 0          test_1      0
# 1          test_1      1
# 2          test_1      2
# 3          test_1      3
# 4          test_1      4
# ..            ...    ...
# 118        test_2     43
# 119        test_2     44
# 120        test_2     45
# 121        test_2     46
# 122        test_2     47
#
# [123 rows x 9 columns]

# %%
# Take a random question and print it in a corresponding format with answers with " * " signs
random_question = final_df.sample(1)

print(random_question["Questions"].values[0] + "\n")
print(f" * {random_question['Ans_1'].values[0]}")
print(f" * {random_question['Ans_2'].values[0]}")
print(f" * {random_question['Ans_3'].values[0]}")
print(f" * {random_question['Ans_4'].values[0]}")
print(f" * {random_question['Ans_5'].values[0]}")
# Out:
# Оцените утверждение:
#
# Я смотрю телевизор или читаю книги
#
#  * Не соглашусь
#  * Скорее не соглашусь
#  * Не знаю
#  * Скорее соглашусь
#  * Соглашусь

# %%
# Save the final df to xlsx
final_df.to_excel("Data/Generated_Questions.xlsx", index=False)
